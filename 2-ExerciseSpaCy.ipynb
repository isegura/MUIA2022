# %% [markdown]
# # Exercise Spacy (https://spacy.io/)
#
# Given an input text, write a function that cleans a text. The text must be cleaned using the following steps:
# - convert to lowercase
# - remove stopwords and special characers
# - remove numerical expresions
#  The function must return the list of lemmas of the cleaned text

# %%
# !pip install spacy
# !python -m spacy download en
import spacy
nlp = spacy.load('en')

# %%
def clean_text(text):
    tokens=[]
    ... #complete
    
    return tokens

# %%
text='Mr Biden ruled out an air strike to minimise civilian casualties and gave a final go-ahead for the special forces raid on Tuesday, monitoring it in real time from the White House situation room as multiple helicopters arrived in Atmeh around midnight on Thursday (22:00 GMT on Wednesday).'
print(clean_text(text))
# Out:
# [Mr, Biden, ruled, out, an, air, strike, to, minimise, civilian, casualties, and, gave, a, final, go, -, ahead, for, the, special, forces, raid, on, Tuesday, ,, monitoring, it, in, real, time, from, the, White, House, situation, room, as, multiple, helicopters, arrived, in, Atmeh, around, midnight, on, Thursday, (, 22:00, GMT, on, Wednesday, ), .]
# ['mr', 'biden', 'rule', 'air', 'strike', 'minimise', 'civilian', 'casualty', 'give', 'final', 'ahead', 'special', 'force', 'raid', 'tuesday', 'monitor', 'real', 'time', 'white', 'house', 'situation', 'room', 'multiple', 'helicopter', 'arrive', 'atmeh', 'midnight', 'thursday', 'gmt', 'wednesday']

# %% [markdown]
# Modifica la versión anterior para que la función devuelva no solo el lema, sino también la categoría morfosintáctica de la palabra.

# %%
text='Mr Biden ruled out an air strike to minimise civilian casualties and gave a final go-ahead for the special forces raid on Tuesday, monitoring it in real time from the White House situation room as multiple helicopters arrived in Atmeh around midnight on Thursday (22:00 GMT on Wednesday).'

def clean_text(text):
    ...

print(clean_text(text))
# Out:
# [Mr, Biden, ruled, out, an, air, strike, to, minimise, civilian, casualties, and, gave, a, final, go, -, ahead, for, the, special, forces, raid, on, Tuesday, ,, monitoring, it, in, real, time, from, the, White, House, situation, room, as, multiple, helicopters, arrived, in, Atmeh, around, midnight, on, Thursday, (, 22:00, GMT, on, Wednesday, ), .]
# [('mr', 'PROPN'), ('biden', 'PROPN'), ('rule', 'VERB'), ('air', 'NOUN'), ('strike', 'NOUN'), ('minimise', 'VERB'), ('civilian', 'ADJ'), ('casualty', 'NOUN'), ('give', 'VERB'), ('final', 'ADJ'), ('ahead', 'NOUN'), ('special', 'ADJ'), ('force', 'NOUN'), ('raid', 'NOUN'), ('tuesday', 'PROPN'), ('monitor', 'VERB'), ('real', 'ADJ'), ('time', 'NOUN'), ('white', 'PROPN'), ('house', 'PROPN'), ('situation', 'NOUN'), ('room', 'NOUN'), ('multiple', 'ADJ'), ('helicopter', 'NOUN'), ('arrive', 'VERB'), ('atmeh', 'PROPN'), ('midnight', 'NOUN'), ('thursday', 'PROPN'), ('gmt', 'PROPN'), ('wednesday', 'PROPN')]
